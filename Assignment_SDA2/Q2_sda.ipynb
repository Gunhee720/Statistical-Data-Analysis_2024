# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot

# %%
import matplotlib as mpl

print(mpl.matplotlib_fname())
# Out:
# C:\ProgramData\Anaconda3\envs\sda2024\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
mpl.rcParams['font.family']='NanumGothic'

# %%
data = pd.read_csv("covid19_utf8.csv",parse_dates=["자치구 기준일"])
data.head()
# Out:
#          자치구 기준일  종로구 전체  종로구 추가  중구 전체  중구 추가  용산구 전체  용산구 추가  성동구 전체  \
# 0  2022.09.18.00   63754      68  57576     70   99069     104  137062
# 1  2022.09.17.00   63686     107  57506     86   98965     151  136920
# 2  2022.09.16.00   63579     146  57420    105   98814     172  136717
# 3  2022.09.15.00   63433     163  57315    111   98642     228  136460
# 4  2022.09.14.00   63270     229  57204    173   98414     343  136187
#
#    성동구 추가  광진구 전체  ...  서초구 전체  서추구 추가  강남구 전체  강남구 추가  송파구 전체  송파구 추가  \
# 0     142  166691  ...  189287     241  243626     271  310841     341
# 1     204  166471  ...  189046     245  243355     296  310500     485
# 2     257  166196  ...  188801     329  243059     397  310015     605
# 3     273  165849  ...  188472     418  242662     521  309410     690
# 4     450  165410  ...  188054     560  242143     692  308720     980
#
#    강동구 전체  강동구 추가   기타 전체  기타 추가
# 0  216999     292  292894    274
# 1  216707     340  292620    498
# ...

# %%
data = pd.read_csv("covid19_utf8.csv", encoding="utf-8")
data["자치구 기준일"] = pd.to_datetime(data["자치구 기준일"], errors='coerce')

# 변환 후 데이터 타입 확인
print(data["자치구 기준일"].dtype)
data
# Out:
# datetime64[ns]
#        자치구 기준일  종로구 전체  종로구 추가  중구 전체  중구 추가  용산구 전체  용산구 추가  성동구 전체  성동구 추가  \
# 0   2022-09-18   63754      68  57576     70   99069     104  137062     142
# 1   2022-09-17   63686     107  57506     86   98965     151  136920     204
# 2   2022-09-16   63579     146  57420    105   98814     172  136717     257
# 3   2022-09-15   63433     163  57315    111   98642     228  136460     273
# 4   2022-09-14   63270     229  57204    173   98414     343  136187     450
# ..         ...     ...     ...    ...    ...     ...     ...     ...     ...
# 953        NaT       0       0      0      0       0       0       0       0
# 954        NaT       0       0      0      0       0       0       0       0
# 955        NaT       0       0      0      0       0       0       0       0
# 956        NaT       3       0      0      0       0       0       0       0
# 957        NaT       3       0      0      0       0       0       0       0
#
# ...

# %%
data_220608 = data.iloc[18:110][::-1]
data_220608
# Out:
#        자치구 기준일  종로구 전체  종로구 추가  중구 전체  중구 추가  용산구 전체  용산구 추가  성동구 전체  성동구 추가  \
# 109 2022-06-01   48506      37  44042     28   73962      62  106338      84
# 108 2022-06-02   48530      24  44056     14   73995      33  106441     103
# 107 2022-06-03   48560      30  44077     21   74065      71  106629     188
# 106 2022-06-04   48592      32  44096     19   74172     107  106738     109
# 105 2022-06-05   48618      26  44127     31   74212      40  106797      59
# ..         ...     ...     ...    ...    ...     ...     ...     ...     ...
# 22  2022-08-27   60604     183  54915    172   94288     314  130683     419
# 21  2022-08-28   60746     142  55058    143   94541     253  131023     340
# 20  2022-08-29   60805      59  55116     58   94651     110  131163     140
# 19  2022-08-30   61082     280  55347    231   95075     425  131684     522
# 18  2022-08-31   61175     211  55470    162   95368     319  132088     445
#
# ...

# %%
data_barplot_220608 = pd.Series(
     data_220608.iloc[-1].values - data_220608.iloc[0].values, 
    index=data_220608.columns
)

# %%
data_barplot_220608 = pd.Series (data_220608.iloc[-1].values-data_220608.iloc[0].values, index=data_220608.columns)
data_barplot_220608 = data_barplot_220608.loc[["종로구 전체", "용산구 전체", "관악구 전체", "강남구 전체", "성동구 전체", "강북구 전체", "송파구 전체"]]
ind = data_barplot_220608.index.values
val = data_barplot_220608.values
data_barplot_220608 = pd.DataFrame({'지역구': ind, '확진자': val})
data_barplot_220608
# Out:
#       지역구    확진자
# 0  종로구 전체  12669
# 1  용산구 전체  21406
# 2  관악구 전체  48189
# 3  강남구 전체  50807
# 4  성동구 전체  25750
# 5  강북구 전체  23602
# 6  송파구 전체  63679

# %%
sns.barplot(x="지역구",y="확진자",data = data_barplot_220608)
# Out:
# <Axes: xlabel='지역구', ylabel='확진자'>

# %%
sns.barplot(x="지역구", y="확진자", data=data_barplot_220608, palette="Blues_r", 
            order=data_barplot_220608.sort_values(by='확진자', ascending=False)['지역구'])
# Out:
# C:\Users\DESKTOP\AppData\Local\Temp\ipykernel_35020\116782786.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="지역구", y="확진자", data=data_barplot_220608, palette="Blues_r",
# <Axes: xlabel='지역구', ylabel='확진자'>

# %%
data_220608["월"] = pd.DatetimeIndex(data_220608["자치구 기준일"]).month
data_220608
# Out:
#        자치구 기준일  종로구 전체  종로구 추가  중구 전체  중구 추가  용산구 전체  용산구 추가  성동구 전체  성동구 추가  \
# 109 2022-06-01   48506      37  44042     28   73962      62  106338      84
# 108 2022-06-02   48530      24  44056     14   73995      33  106441     103
# 107 2022-06-03   48560      30  44077     21   74065      71  106629     188
# 106 2022-06-04   48592      32  44096     19   74172     107  106738     109
# 105 2022-06-05   48618      26  44127     31   74212      40  106797      59
# ..         ...     ...     ...    ...    ...     ...     ...     ...     ...
# 22  2022-08-27   60604     183  54915    172   94288     314  130683     419
# 21  2022-08-28   60746     142  55058    143   94541     253  131023     340
# 20  2022-08-29   60805      59  55116     58   94651     110  131163     140
# 19  2022-08-30   61082     280  55347    231   95075     425  131684     522
# 18  2022-08-31   61175     211  55470    162   95368     319  132088     445
#
# ...

# %%
data_boxplot_220608 = data_220608[["종로구 추가", "강남구 추가", "관악구 추가", "용산구 추가","월"]]
data_boxplot_220608
# Out:
#      종로구 추가  강남구 추가  관악구 추가  용산구 추가  월
# 109      37     311     140      62  6
# 108      24     217      77      33  6
# 107      30     120     112      71  6
# 106      32     143      73     107  6
# 105      26     111     102      40  6
# ..      ...     ...     ...     ... ..
# 22      183     741     723     314  8
# 21      142     640     681     253  8
# 20       59     326     284     110  8
# 19      280    1114     969     425  8
# 18      211     782     775     319  8
#
# [92 rows x 5 columns]

# %%
import pandas as pd

# 데이터프레임 변환
data_transformed = pd.melt(data_boxplot_220608, id_vars=["월"], 
                           value_vars=["종로구 추가", "강남구 추가", "관악구 추가", "용산구 추가"], 
                           var_name="지역구", value_name="확진자")

data_transformed
# Out:
#      월     지역구  확진자
# 0    6  종로구 추가   37
# 1    6  종로구 추가   24
# 2    6  종로구 추가   30
# 3    6  종로구 추가   32
# 4    6  종로구 추가   26
# ..  ..     ...  ...
# 363  8  용산구 추가  314
# 364  8  용산구 추가  253
# 365  8  용산구 추가  110
# 366  8  용산구 추가  425
# 367  8  용산구 추가  319
#
# [368 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 데이터프레임 변환 (기존 변환 코드)
data_transformed = pd.melt(data_boxplot_220608, id_vars=["월"], 
                           value_vars=["종로구 추가", "강남구 추가", "관악구 추가", "용산구 추가"], 
                           var_name="지역구", value_name="확진자")
flierprops = dict(marker='^', color="black", markersize=5, markerfacecolor="black", markeredgecolor="black")

# boxplot 생성
ax = sns.boxplot(data=data_transformed, x="월", y="확진자", hue="지역구",flierprops=flierprops)

# 현재 범례의 핸들과 레이블 가져오기
handles, _ = ax.get_legend_handles_labels()

# 새로운 레이블로 범례 설정
ax.legend(handles, ["종로구", "강남구", "관악구", "용산구"], title='지역구')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 박스 플롯 그리기
month_plot=sns.boxplot(data=data_transformed, x="지역구", y="확진자", hue="월", 
            palette={6: (0.19, 0.45, 0.63, 1.00), 7: (0.88, 0.51, 0.17, 1.00), 8:(0.23, 0.57, 0.23, 1.00)},flierprops=flierprops)


handles2, _ = month_plot.get_legend_handles_labels()
month_plot.legend(handles2,["6", "7", "8"],title='월')
plt.show()
